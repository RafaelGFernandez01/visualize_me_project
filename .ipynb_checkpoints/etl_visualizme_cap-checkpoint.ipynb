# %%
# Importing variables
import pandas as pd
from pandas.io import sql
from sqlalchemy import create_engine, inspect

# %% [markdown]
# ### Extracting CSV into DataFrame

# %%
data_file = "./Resources/data.xlsx"
data_df = pd.read_excel(data_file)
data_df.head()
# Out:
#      HTS Code                               HTS Code Description  \
# 0  3206110000  PIGMENTS AND PREPARE. BASED ON TITANIUM DIOXID...
# 1  3206110000  PIGMENTS AND PREPARE. BASED ON TITANIUM DIOXID...
# 2  3206110000  PIGMENTS AND PREPARE. BASED ON TITANIUM DIOXID...
# 3  3206110000  PIGMENTS AND PREPARE. BASED ON TITANIUM DIOXID...
# 4  3206110000  PIGMENTS AND PREPARE. BASED ON TITANIUM DIOXID...
#
#                 Custom         DUA       Date        ETA           B/L  \
# 0  MARITIMA DEL CALLAO  051833 | 1 2021-02-09 2021-02-14  118-2021-236
# 1  MARITIMA DEL CALLAO  080268 | 1 2021-02-26 2021-02-28  118-2021-344
# 2  MARITIMA DEL CALLAO  111921 | 3 2021-03-23 2021-03-26  118-2021-640
# 3  MARITIMA DEL CALLAO  026814 | 1 2021-01-21 2021-01-22   118-2021-67
# 4  MARITIMA DEL CALLAO  040921 | 5 2021-02-01 2021-02-06  118-2021-191
#
#         Tax ID                                           Importer  \
# 0  20100312736  MERCANTIL S A                                 ...
# ...

# %%
port_names = "./Resources/world_port_names.xlsx"
port_df = pd.read_excel(port_names)
port_names()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-10-0aa2ff1741c3> in <module>
#       1 port_names = "./Resources/world_port_names.xlsx"
# ----> 2 port_df = pd.read_excel(port_names)
#       3 port_names()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %% [markdown]
# ### Transforming data_df
